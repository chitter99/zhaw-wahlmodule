# %%
import pandas as pd

# %%
df = pd.read_excel('./Angebot_Wahlpflichtmodule_2024-25.ods')
df
# Out:
#                       Verantwortlich (MVP)   Stammkürzel  \
# 0                       Abegglen Christian  MTV.SYAT1-EN
# 1    Abegglen Christian,Putzi-Plesko Hanna     WV.SEN-EN
# 2                        Ackermann Philipp       WV.GADE
# 3                        Ackermann Philipp        WV.VC1
# 4                        Ackermann Philipp        WV.VC2
# ..                                     ...           ...
# 219                            Wulf Jochen       WIV.SEL
# 220                            Wulf Jochen       WIV.SOM
# 221                       Wyrsch Sigisbert      XWV.DSV1
# 222                       Zipper Christian    WVK.BW-NIK
# 223                       Zipper Christian        WVK.RM
#
#                               Modulbezeichnung Deutsch Institut/Zentrum  \
# 0                  Systems and Automation Technology 1              IMS
# 1                                              Sensors              IMS
# ...

# %%
df = df.rename({
    "Verantwortlich (MVP)": "MVP",
})

# %%
# Remove blockwoche and hackathon modules
df = df[~df["Modulbezeichnung Deutsch"].str.contains("blockwoche|hackathon|blockweek", case=False)]

# %% [markdown]
# ### Modulgruppe DS5

# %%
DS5 = df[df["Modulgruppe"].str.contains("DS5") & df["Modulart"].str.contains("WPFM Kontext")]

# %% [markdown]
# 5. Semester

# %%
DS5[DS5["TZ Durchführungssemester"].str.contains("5.")]
# Out:
#                   Verantwortlich (MVP)  Stammkürzel  \
# 9                        Agius William  XWK.ICAM-EN
# 29                         Bürgin Reto    WVK.DABEF
# 47                     Del Duce Andrea      WVK.SWA
# 53                    Dingerkus Stefan      WVK.ITR
# 54                    Dingerkus Stefan     WVK.PATR
# 63                        Eberle Armin   WVK.CLEANT
# 84                              Gürboy     WVK.KONF
# 100                     Järmann Thomas     XXK.FUKI
# 101                      Kammer Adrian     WVK.ENVE
# 103                      Kammer Adrian     WVK.TFEL
# 110                       Koll Stephan       WVK.PM
# 122              Meier Daniel Matthias   WVK.TESYNC
# 164              Sauter-Servaes Thomas     WVK.SMOB
# 179                       Spada Matteo     WVK.RESE
# 192                     Studer Patrick   WVK.EAP-EN
# 199                   Ulli-Beer Silvia     WVK.INTM
# 203  Ulli-Beer Silvia, Speich Matthias     WVK.DEKA
# ...

# %% [markdown]
# 6. Semester

# %%
DS5[DS5["TZ Durchführungssemester"].str.contains("6.")]
# Out:
#     Verantwortlich (MVP)  Stammkürzel  \
# 9          Agius William  XWK.ICAM-EN
# 32          Burri Adrian     WVK.CECO
# 47       Del Duce Andrea      WVK.SWA
# 64          Eberle Armin      WVK.MMA
# 65          Eberle Armin      WVK.WEF
# 102        Kammer Adrian    WVK.IVEST
# 105        Kammer Adrian     WVK.ZURO
# 192       Studer Patrick   WVK.EAP-EN
#
#                               Modulbezeichnung Deutsch Institut/Zentrum  \
# 9           Intercultural Communication and Management              ZAV
# 32                                    Circular Economy              IPP
# 47      Schlüsselkompetenz Wissenschaftliches Arbeiten              INE
# 64                      Marketing und Marktbearbeitung              INE
# 65   Wirtschaftliches/Gesellschaftliches Umfeld als...              INE
# 102                       Investition und Finanzierung              INE
# 105                                  Zukunft Rohstoffe              INE
# ...

# %% [markdown]
# ### Modulgruppe DS6

# %%
DS6 = df[df["Modulgruppe"].str.contains("DS6") & df["Modulart"].str.contains("WPFM Fach")]

# %% [markdown]
# 5. Semester

# %%
DS6[DS6["TZ Durchführungssemester"].str.contains("5.")]
# Out:
#        Verantwortlich (MVP) Stammkürzel        Modulbezeichnung Deutsch  \
# 21   Bohnert Thomas Michael  WV.CCP1-EN               Cloud Computing 1
# 39      Chavarriaga Ricardo    WV.RL-EN          Reinforcement Learning
# 59               Doran Hans  WV.IOT1-EN            Internet of Things 1
# 109           Knapp Evelynd      WV.MKS  Modellierung Komplexer Systeme
# 152          Rosset Josquin   WV.DIP-EN      Digital Image Processing 1
# 167     Scheidegger Stephan    WV.BMSY1       Biomedizinische Systeme 1
# 218             Wulf Jochen  WIV.SEG-EN      Service Engineering Basics
#
#     Institut/Zentrum Verantwortlich (MVP).1              Modulgruppe  \
# 21              InIT                   bohe                  DS6;IT6
# 39               CAI                   char                  DS6,IT6
# 59              InES                   donn              DS6,ET5,IT6
# 109              ICP                   hube                      DS6
# ...

# %% [markdown]
# 6. Semester

# %%
DS6[DS6["TZ Durchführungssemester"].str.contains("6.")]
# Out:
#       Verantwortlich (MVP)  Stammkürzel            Modulbezeichnung Deutsch  \
# 58              Doran Hans  WV.DSIOT-EN      Data Science in Industrial IoT
# 119         Marti Christof   WV.CCP2-EN                   Cloud Computing 2
# 168    Scheidegger Stephan     WV.BMSY2           Biomedizinische Systeme 2
# 172  Schilling Frank-Peter   WV.CVDL-EN  Computer Vision with Deep Learning
# 177  Schilling Frank-Peter  WV.MLOPS-EN         Machine Learning Operations
# 185       Stadelmann Thilo    WV.AI2-EN           Artificial Intelligence 2
# 219            Wulf Jochen      WIV.SEL           Service Engineering Labor
#
#     Institut/Zentrum Verantwortlich (MVP).1          Modulgruppe  \
# 58              InES                   donn              DS6;IT6
# 119             InIT                   mach              DS6;IT6
# 168       IAMP / ICP                   scst  DS6,ST5-MED,ST5-ROM
# 172              CAI                   scik              DS6,IT6
# ...
